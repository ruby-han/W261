# %%
# %run /Users/rubyhan@berkeley.edu/team28/Final_Project/Imports
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
LABEL = ['DEP_DEL15']

CONT_FEATURES = [
    'CRS_ELAPSED_TIME',
    'AIRPORT_LAT_ORIGIN',
    'AIRPORT_LONG_ORIGIN',
    'AIRPORT_LAT_DEST',
    'AIRPORT_LONG_DEST',
    
    'ORIGIN_WEATHER_ELEVATION',
    'ORIGIN_WEATHER_WND_DIRECTION_ANGLE-AVG',
    'ORIGIN_WEATHER_WND_SPEED_RATE-AVG',
    'ORIGIN_WEATHER_CIG_CEILING_HEIGHT_DIMENSION-AVG',
    'ORIGIN_WEATHER_VIS_DISTANCE_DIMENSION-AVG',
#     'ORIGIN_WEATHER_TMP_AIR_TEMP-AVG',
    'ORIGIN_WEATHER_DEW_POINT_TEMP-AVG',
    'ORIGIN_WEATHER_SLP_SEA_LEVEL_PRES-AVG',
    
    'DEST_WEATHER_ELEVATION',
    'DEST_WEATHER_WND_DIRECTION_ANGLE-AVG',
    'DEST_WEATHER_WND_SPEED_RATE-AVG',
    'DEST_WEATHER_CIG_CEILING_HEIGHT_DIMENSION-AVG',
    'DEST_WEATHER_VIS_DISTANCE_DIMENSION-AVG',
#     'DEST_WEATHER_TMP_AIR_TEMP-AVG',
    'DEST_WEATHER_DEW_POINT_TEMP-AVG',
    'DEST_WEATHER_SLP_SEA_LEVEL_PRES-AVG'
]

CAT_FEATURES = [
#     'YEAR',
#     'QUARTER',
    'MONTH',
    'DAY_OF_MONTH',
    'DAY_OF_WEEK',
#     'FL_DATE',
    'CRS_DEP_TIME_UTC_HOUR',
#     'CRS_DEP_TIME_HOUR',
  
#     'PRIOR_ARR_DEL15',
#     'PRIOR_DEP_DEL15',
    
    'OP_UNIQUE_CARRIER',
    'TAIL_NUM',
    'ORIGIN_AIRPORT_ID',
    'ORIGIN',
    'DEST_AIRPORT_ID',
    'DEST',
    'DEP_TIME_BLK',
#     'ARR_TIME_BLK',
#     'ID',
    
]

TOT_FEATURES = LABEL + CONT_FEATURES + CAT_FEATURES
# len(TOT_FEATURES)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Ease
df = joined_full_processed_df[TOT_FEATURES].cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df.select('CRS_DEP_TIME_UTC_HOUR').display().head(10)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CRS_DEP_TIME_UTC_HOUR</th></tr></thead><tbody><tr><td>2018-01-03T12:00:00.000+0000</td></tr><tr><td>2018-03-08T11:00:00.000+0000</td></tr><tr><td>2019-05-13T21:00:00.000+0000</td></tr><tr><td>2019-06-03T22:00:00.000+0000</td></tr><tr><td>2019-08-12T22:00:00.000+0000</td></tr><tr><td>2019-12-23T17:00:00.000+0000</td></tr><tr><td>2015-08-05T01:00:00.000+0000</td></tr><tr><td>2015-08-05T01:00:00.000+0000</td></tr><tr><td>2015-09-17T18:00:00.000+0000</td></tr><tr><td>2015-10-06T01:00:00.000+0000</td></tr><tr><td>2015-10-06T01:00:00.000+0000</td></tr><tr><td>2017-04-12T01:00:00.000+0000</td></tr><tr><td>2017-04-12T01:00:00.000+0000</td></tr><tr><td>2017-12-09T19:00:00.000+0000</td></tr><tr><td>2018-08-24T01:00:00.000+0000</td></tr><tr><td>2018-12-25T02:00:00.000+0000</td></tr><tr><td>2019-01-03T19:00:00.000+0000</td></tr><tr><td>2019-03-23
000+0000</td><td>31</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>32</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>33</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>34</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>35</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>36</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>37</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>38</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>39</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>40</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>41</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>42</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>43</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>44</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>45</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>46</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>47</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>48</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>49</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>50</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>51</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>52</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>53</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>54</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>55</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>56</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>57</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>58</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>59</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>60</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>61</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>62</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>63</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>64</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>65</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>66</td></tr><tr><td>2 ...

# %%
df_ordered.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 30847753</div>

# %%
def cv_folds(data = None, folds = 1, train_pct = .8, simple_splits = False):
    
    # Empty list to store dataframes for each fold
    train_dfs = []
    val_dfs = []
    
    # Create simple folds by full train year, val year
    if simple_splits:
        for year in [2015, 2016, 2017]:
            
            train_df = data.where(f.col('CRS_DEP_TIME_UTC_HOUR') == year)
            val_df = data.where(f.col('CRS_DEP_TIME_UTC_HOUR') == (year + 1))
            
            train_dfs.append(train_df)
            val_dfs.append(val_df)
    
    # Create folds by number of folds, train/test split %
    else:
        data_size = data.count()
        
        for k in range(folds): 

            # Calculate total size of each fold
            fold_size = data_size/folds

            # Find range of `SPLIT_ID` for train and val
            train_ids = ((fold_size * k) + 0, 
                         int(fold_size * k + fold_size*.8))

            val_ids = (train_ids[1] + 1, 
                       fold_size * k + fold_size)            

            # Split the data
            train_df = data.where(f.col('SPLIT_ID').between(train_ids[0], train_ids[1]))
            val_df = data.where(f.col('SPLIT_ID').between(val_ids[0], val_ids[1]))

            # store data
            train_dfs.append(train_df)
            val_dfs.append(val_df)

    return train_dfs, val_dfs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sample = df_ordered.filter(f.col('SPLIT_ID') < 200000).cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sample.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- DEP_DEL15: double (nullable = true)
# -- CRS_ELAPSED_TIME: double (nullable = true)
# -- AIRPORT_LAT_ORIGIN: double (nullable = true)
# -- AIRPORT_LONG_ORIGIN: double (nullable = true)
# -- AIRPORT_LAT_DEST: double (nullable = true)
# -- AIRPORT_LONG_DEST: double (nullable = true)
# -- ORIGIN_WEATHER_ELEVATION: double (nullable = true)
# -- ORIGIN_WEATHER_WND_DIRECTION_ANGLE-AVG: double (nullable = true)
# -- ORIGIN_WEATHER_WND_SPEED_RATE-AVG: double (nullable = true)
# -- ORIGIN_WEATHER_CIG_CEILING_HEIGHT_DIMENSION-AVG: double (nullable = true)
# -- ORIGIN_WEATHER_VIS_DISTANCE_DIMENSION-AVG: double (nullable = true)
# -- ORIGIN_WEATHER_DEW_POINT_TEMP-AVG: double (nullable = true)
# -- ORIGIN_WEATHER_SLP_SEA_LEVEL_PRES-AVG: double (nullable = true)
# -- DEST_WEATHER_ELEVATION: double (nullable = true)
# -- DEST_WEATHER_WND_DIRECTION_ANGLE-AVG: double (nullable = true)
# -- DEST_WEATHER_WND_SPEED_RATE-AVG: double (nullable = true)
# -- DEST_WEATHER_CIG_CEILING_HEIGHT_DIMENSION-AVG: double (nullable = true)
# -- DEST_WEATHER_VIS_DISTANCE_DIMENSION-AVG: double (nullable = true)
# -- DEST_WEATHER_DEW_POINT_TEMP-AVG: double (nullable = true)
# -- DEST_WEATHER_SLP_SEA_LEVEL_PRES-AVG: double (nullable = true)
# -- MONTH: integer (nullable = true)
# -- DAY_OF_MONTH: integer (nullable = true)
# -- DAY_OF_WEEK: integer (nullable = true)
# -- CRS_DEP_TIME_UTC_HOUR: timestamp (nullable = true)
# -- OP_UNIQUE_CARRIER: string (nullable = true)
# -- TAIL_NUM: string (nullable = true)
# -- ORIGIN_AIRPORT_ID: integer (nullable = true)
# -- ORIGIN: string (nullable = true)
# -- DEST_AIRPORT_ID: integer (nullable = true)
# -- DEST: string (nullable = true)
# -- DEP_TIME_BLK: string (nullable = true)
# -- SPLIT_ID: long (nullable = false)
#
# </div>

# %%
simple = False

def test_f(simple = True):
    if not simple: 
        print('false')
    else:
        print('true')
        
test_f(simple)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">false
# </div>

# %%
sample.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: 199999</div>

# %%
tr, va = cv_folds(sample, 2, .8)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
va[1].count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[122]: 20000</div>

# %%
tr2[1].count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[84]: 40000</div>

# %%
val_df_1.agg({'SPLIT_ID': 'max', 'SPLIT_ID': 'min'}).show()
train_df_1.agg({'SPLIT_ID': 'max', 'SPLIT_ID': 'min'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+
# min(SPLIT_ID)|
# +-------------+
#        160000|
# +-------------+
#
# +-------------+
# min(SPLIT_ID)|
# +-------------+
#             1|
# +-------------+
#
# </div>

# %%
for i in range(2):
    print(i)
    tr[i].agg({'SPLIT_ID': 'min'}).show()
    tr[i].agg({'SPLIT_ID': 'max'}).show()
    va[i].agg({'SPLIT_ID': 'min'}).show()
    va[i].agg({'SPLIT_ID': 'max'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0
# +-------------+
# min(SPLIT_ID)|
# +-------------+
#             1|
# +-------------+
#
# +-------------+
# max(SPLIT_ID)|
# +-------------+
#         79999|
# +-------------+
#
# +-------------+
# min(SPLIT_ID)|
# +-------------+
#         80000|
# +-------------+
#
# +-------------+
# max(SPLIT_ID)|
# +-------------+
#         99999|
# +-------------+
#
# 1
# +-------------+
# min(SPLIT_ID)|
# +-------------+
#        100000|
# +-------------+
#
# +-------------+
# max(SPLIT_ID)|
# +-------------+
#        179999|
# +-------------+
#
# +-------------+
# min(SPLIT_ID)|
# +-------------+
#        180000|
# +-------------+
#
# +-------------+
# max(SPLIT_ID)|
# +-------------+
#        199999|
# +-------------+
#
# </div>

# %%
data_size = sample.count()
# fold_size = data_size/folds

# train_ids = (0, int(fold_size*.8))
# val_ids = (train_ids[1] + 1, fold_size)



# train_df = data.where(f.col('SPLIT_ID') < train_ids[1])
data_size
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: 1460</div>

# %%
sample.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DEP_DEL15</th><th>CRS_ELAPSED_TIME</th><th>AIRPORT_LAT_ORIGIN</th><th>AIRPORT_LONG_ORIGIN</th><th>AIRPORT_LAT_DEST</th><th>AIRPORT_LONG_DEST</th><th>ORIGIN_WEATHER_ELEVATION</th><th>ORIGIN_WEATHER_WND_DIRECTION_ANGLE-AVG</th><th>ORIGIN_WEATHER_WND_SPEED_RATE-AVG</th><th>ORIGIN_WEATHER_CIG_CEILING_HEIGHT_DIMENSION-AVG</th><th>ORIGIN_WEATHER_VIS_DISTANCE_DIMENSION-AVG</th><th>ORIGIN_WEATHER_DEW_POINT_TEMP-AVG</th><th>ORIGIN_WEATHER
-93.221802</td><td>26.072599</td><td>-80.152702</td><td>265.8</td><td>220.0</td><td>46.0</td><td>6401.0</td><td>16093.0</td><td>-161.0</td><td>10174.0</td><td>3.4</td><td>117.5</td><td>19.25</td><td>6147.75</td><td>14483.75</td><td>206.0</td><td>10214.0</td><td>1</td><td>1</td><td>4</td><td>2015-01-01T07:00:00.000+0000</td><td>NK</td><td>N528NK</td><td>13487</td><td>MSP</td><td>11697</td><td>FLL</td><td>0001-0559</td><td>5</td></tr><tr><td>0.0</td><td>215.0</td><td>40.78839874267578</td><td>-111.97799682617188</td><td>33.6367</td><td>-84.428101</td><td>1287.8</td><td>140.0</td><td>21.0</td><td>22000.0</td><td>16093.0</td><td>-161.0</td><td>10255.0</td><td>307.8</td><td>330.0</td><td>21.0</td><td>6096.0</td><td>16093.0</td><td>-17.0</td><td>10280.0</td><td>1</td><td>1</td><td>4</td><td>2015 ...

# %%
sample.withColumn('Year', f.year(f.col("CRS_DEP_TIME_UTC_HOUR"))).select(["CRS_DEP_TIME_UTC_HOUR", 'Year']).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CRS_DEP_TIME_UTC_HOUR</th><th>Year</th></tr></thead><tbody><tr><td>2015-01-01T06:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T07:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T07:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T07:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T07:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T08:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T09:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2015</td></tr><tr><td>2015-01-01T10:00:00.000+0000</td><td>2 ...

# %%
sample.where(f.year(f.col('CRS_DEP_TIME_UTC_HOUR')) == 2015).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DEP_DEL15</th><th>CRS_ELAPSED_TIME</th><th>AIRPORT_LAT_ORIGIN</th><th>AIRPORT_LONG_ORIGIN</th><th>AIRPORT_LAT_DEST</th><th>AIRPORT_LONG_DEST</th><th>ORIGIN_WEATHER_ELEVATION</th><th>ORIGIN_WEATHER_WND_DIRECTION_ANGLE-AVG</th><th>ORIGIN_WEATHER_WND_SPEED_RATE-AVG</th><th>ORIGIN_WEATHER_CIG_CEILING_HEIGHT_DIMENSION-AVG</th><th>ORIGIN_WEATHER_VIS_DISTANCE_DIMENSION-AVG</th><th>ORIGIN_WEATHER_DEW_POINT_TEMP-AVG</th><th>ORIGIN_WEATHER_SLP_SEA_LEVEL_PRES-AVG</th><th>DEST_WEATHER_ELEVATION</th><th>DEST_WEATHER_WND_DIRECTION_ANGLE-AVG</th><th>DEST_WEATHER_WND_SPEED_RATE-AVG</th><th>DEST_WEATHER_CIG_CEILING_HEIGHT_DIMENSION-AVG</th><th>DEST_WEATHER_VIS_DISTANCE_DIMENSION-AVG</th><th>DEST_WEATHER_DEW_POINT_TEMP-AVG</th><th>DEST_WEATHER_SLP_SEA_LEVEL_PRES-AVG</th><th>MONTH</th><th>DAY_OF_MONTH</th><th>DAY_OF_WEEK</th><th>CRS_DEP_TIME_UTC_HOUR</th><th>OP_UNIQUE_CARRIER</th><th>TAIL_NUM</th><th>ORIGIN_AIRPORT_ID</th><th>ORIGIN</th><th>DEST_AIRPORT_ID</th><th>DEST</th><th>DEP_TIME_BLK</th><th>SPLIT_ID</th></tr></thead><tbody><tr><td>0.0</td><