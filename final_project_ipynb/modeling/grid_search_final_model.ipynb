# %%
# %run /Users/rubyhan@berkeley.edu/team28/Final_Project/Modeling/end_to_end_pipeline

# %%
df = model_transformed_train_2015_18_new_pagerank_noncontscale_df.select('DEP_DEL15', 'ALL_FEATURES_VA')
df = df.na.drop()

# %%
# Log Reg
# MAX_ITERS = [16, 32, 64]
# ALPHAS = [.1, .2, .3] 
# LAMBDAS = [.01, .05, .1]

# param_list = [MAX_ITERS, ALPHAS, LAMBDAS]
# names = ['MAX_ITERS', 'ALPHAS', 'LAMBDAS']

# Random Forest
# NUM_TREES = [128,256,512]
# MAX_DEPTH = [10,20,40,80]
# MAX_BINS=[128,256,512]
# param_list = [NUM_TREES,MAX_DEPTH,MAX_BINS]
# names = ['NUM_TREES','MAX_DEPTH','MAX_BINS']

# GBT
MAX_ITERS = [6]
MAX_DEPTH = [6, 10]
MAX_BINS = [256, 280]
STEP_SIZE = [0.1, 0.2]

param_list = [MAX_ITERS, MAX_DEPTH, MAX_BINS, STEP_SIZE]
names = ['MAX_ITERS', 'MAX_DEPTH', 'MAX_BINS', 'STEP_SIZE']

gridsearch(df, k_folds=3, param_list, names, random_shuffle_top_N=5, model_type='gbt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
# Looping through param:[(&#39;MAX_ITERS&#39;, 6), (&#39;MAX_DEPTH&#39;, 6), (&#39;MAX_BINS&#39;, 256), (&#39;STEP_SIZE&#39;, 0.1)]
#
# 0-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.600 		 0.560
# Precision: 		0.744 		 0.372
# Accuracy: 		0.696 		 0.784
# F0.5 score: 		0.710 		 0.398
# F2 score: 		0.624 		 0.508
# F1 score: 		0.664 		 0.447
#
# 1-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.614 		 0.596
# Precision: 		0.753 		 0.405
# Accuracy: 		0.706 		 0.777
# F0.5 score: 		0.720 		 0.432
# F2 score: 		0.638 		 0.544
# F1 score: 		0.677 		 0.482
#
# 2-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.610 		 0.565
# Precision: 		0.748 		 0.370
# Accuracy: 		0.702 		 0.780
# F0.5 score: 		0.715 		 0.397
# F2 score: 		0.634 		 0.511
# F1 score: 		0.672 		 0.447
#
# Looping through param:[(&#39;MAX_ITERS&#39;, 6), (&#39;MAX_DEPTH&#39;, 10), (&#39;MAX_BINS&#39;, 280), (&#39;STEP_SIZE&#39;, 0.1)]
#
# 0-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.627 		 0.582
# Precision: 		0.751 		 0.372
# Accuracy: 		0.709 		 0.782
# F0.5 score: 		0.722 		 0.401
# F2 score: 		0.648 		 0.523
# F1 score: 		0.683 		 0.454
#
# 1-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.646 		 0.623
# Precision: 		0.757 		 0.402
# Accuracy: 		0.719 		 0.772
# F0.5 score: 		0.731 		 0.432
# F2 score: 		0.665 		 0.561
# F1 score: 		0.697 		 0.488
#
# 2-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.628 		 0.568
# Precision: 		0.762 		 0.385
# Accuracy: 		0.716 		 0.789
# F0.5 score: 		0.731 		 0.412
# F2 score: 		0.651 		 0.519
# F1 score: 		0.688 		 0.459
#
# Looping through param:[(&#39;MAX_ITERS&#39;, 6), (&#39;MAX_DEPTH&#39;, 10), (&#39;MAX_BINS&#39;, 256), (&#39;STEP_SIZE&#39;, 0.1)]
#
# 0-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.625 		 0.577
# Precision: 		0.752 		 0.375
# Accuracy: 		0.709 		 0.784
# F0.5 score: 		0.722 		 0.403
# F2 score: 		0.646 		 0.521
# F1 score: 		0.682 		 0.455
#
# 1-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.643 		 0.620
# Precision: 		0.757 		 0.402
# Accuracy: 		0.719 		 0.773
# F0.5 score: 		0.732 		 0.433
# F2 score: 		0.663 		 0.560
# F1 score: 		0.696 		 0.488
#
# 2-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.626 		 0.567
# Precision: 		0.763 		 0.385
# Accuracy: 		0.716 		 0.789
# F0.5 score: 		0.731 		 0.412
# F2 score: 		0.649 		 0.518
# F1 score: 		0.688 		 0.459
#
# Looping through param:[(&#39;MAX_ITERS&#39;, 6), (&#39;MAX_DEPTH&#39;, 6), (&#39;MAX_BINS&#39;, 280), (&#39;STEP_SIZE&#39;, 0.1)]
#
# 0-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.601 		 0.561
# Precision: 		0.743 		 0.371
# Accuracy: 		0.696 		 0.783
# F0.5 score: 		0.709 		 0.398
# F2 score: 		0.625 		 0.509
# F1 score: 		0.664 		 0.446
#
# 1-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.614 		 0.594
# Precision: 		0.753 		 0.405
# Accuracy: 		0.706 		 0.777
# F0.5 score: 		0.720 		 0.433
# F2 score: 		0.637 		 0.543
# F1 score: 		0.676 		 0.482
#
# 2-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.611 		 0.565
# Precision: 		0.747 		 0.369
# Accuracy: 		0.702 		 0.779
# F0.5 score: 		0.715 		 0.397
# F2 score: 		0.634 		 0.511
# F1 score: 		0.672 		 0.447
#
# Looping through param:[(&#39;MAX_ITERS&#39;, 6), (&#39;MAX_DEPTH&#39;, 10), (&#39;MAX_BINS&#39;, 256), (&#39;STEP_SIZE&#39;, 0.2)]
#
# 0-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.637 		 0.588
# Precision: 		0.753 		 0.371
# Accuracy: 		0.714 		 0.781
# F0.5 score: 		0.727 		 0.401
# F2 score: 		0.657 		 0.527
# F1 score: 		0.690 		 0.455
#
# 1-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.651 		 0.621
# Precision: 		0.761 		 0.406
# Accuracy: 		0.723 		 0.775
# F0.5 score: 		0.736 		 0.436
# F2 score: 		0.670 		 0.561
# F1 score: 		0.702 		 0.491
#
# 2-Fold:
#
#  		Train Metrics 	 Validation Metrics
#
# Recall: 		0.637 		 0.571
# Precision: 		0.764 		 0.386
# Accuracy: 		0.720 		 0.789
# F0.5 score: 		0.735 		 0.413
# F2 score: 		0.659 		 0.521
# F1 score: 		0.695 		 0.461
# GridSearch
# Best Valid f0.5 Score: 0.436
# Best Parameters: {&#39;maxIter&#39;: 6, &#39;maxDepth&#39;: 10, &#39;maxBins&#39;: 256, &#39;stepSize&#39;: 0.2}
# </div>
