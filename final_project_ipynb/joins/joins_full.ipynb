# %% [markdown]
# #### Load Data

# %%
# %run /Users/rubyhan@berkeley.edu/team28/Final_Project/Imports

# %%
# # Load data from Saved Parquet Files | 

# ICAO_station_mapping = spark.read.parquet(f'{blob_url}/ICAO_station_mapping').cache()

# Quick rename for sake of brevity
flights = airline_full_processed_df
stations = ICAO_station_mapping
weather = weather_full_processed_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(weather_full_processed_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>STATION</th><th>DATE</th><th>LATITUDE</th><th>LONGITUDE</th><th>ELEVATION</th><th>NAME</th><th>HOUR</th><th>WND_DIRECTION_ANGLE</th><th>WND_TYPE_CODE</th><th>WND_SPEED_RATE</th><th>CIG_CEILING_HEIGHT_DIMENSION</th><th>CIG_CEILING_DETERMINATION_CODE</th><th>CIG_CAVOK_CODE</th><th>VIS_DISTANCE_DIMENSION</th><th>VIS_VARIABILITY_CODE</th><th>TMP_AIR_TEMP</th><th>DEW_POINT_TEMP</th><th>SLP_SEA_LEVEL_PRES</th><th>VALID_WEATHER_DATA</th><th>WND_DIRECTION_ANGLE-AVG</th><th>WND_SPEED_RATE-AVG</th><th>CIG_CEILING_HEIGHT_DIMENSION-AVG</th><th>VIS_DISTANCE_DIMENSION-AVG</th><th>TMP_AIR_TEMP-AVG</th><th>DEW_POINT_TEMP-AVG</th><th>SLP_SEA_LEVEL_PRES-AVG</th></tr></thead><tbody><tr><td>70388899999</td><td>2018-01-07T21:56:00.000+0000</td><td>64.3710833</td><td>-161.223972</td><td>7.0</td><td>SHAKTOOLIK AIRPORT, AK US</td><td>2018-01-07T21:00:00.000+0000</td><td>180</td><td>N</td><td>26</td><td>792</td><td>C</td><td>N</td><td>16093</td><td>null</td><td>-28</td><td>-39</td><td>10107</td><td>1</td><td>180.0</td><td>26.0</td><td>792.0</td><td>16093.0</td><td>-28.0</td><td>-39.0</td><td>10107.0</td></tr><tr><td>70388899999</td><td>2018-01-07T22:56:00.000+0000</td><td>64.3710833</td><td>-161.223972</td><td>7.0</td><td>SHAKTOOLIK AIRPORT, AK US</td><td>2018-01-07T22:00:00.000+0000</td><td>150</td><td>N</td><td>46</td><td>732</td><td>C</td><td>N</td><td>14484</td><td>null</td><td>-33</td><td>-67</td><td>10108</td><td>1</td><td>150.0</td><td>46.0</td><td>732.0</td><td>14484.0</td><td>-33.0</td><td>-67.0</td><td>10108.0</td></tr><tr><td>70388899999</td><td>2018-01-07T23:56:00.000+0000</td><td>64.3710833</td><td>-161.223972</td><td>7.0</td><td>SHAKTOOLIK AIRPORT, AK US</td><td>2018-01-07T23:00:00.000+0000</td><td>100</td><td>N</td><td>21</td><td>2591</td><td>9</td><td>N</td><td>16093</td><td>null</td><td>-33</td><td>-67</td><td>10112</td><td>1</td><td>100.0</td><td>21.0</td><td>2591.0</td><td>16093.0</td><td>-33.0</td><td>-67.0</td><td>10112.0</td></tr><tr><td>70388899999</td><td>2018-01-08T00:56:00.000+0000</td><td>64.3710833</td><td>-161.223972</td><td>7.0</td><td>SHAKTOOLIK AIRPORT, AK US</td><td>2018-01-08T00:00:00.000+0000</td><td>null</td><td>C</td><td>0</td><td>1036</td><td>9</td><td>N</td><td>16093</td><td>null</td><td>-50</td><td>-67</td><td>10117</td><td>0</td><td>143.33333333333334</td><td>0.0</td><td>1036.0</td><td>16093.0</td><td>-50.0</td><td>-67.0</td><td>10117.0</td></tr><tr><td>70388899999</td><td>2018-01-08T01:56:00.000+0000</td><td>64.3710833</td><td>-161.223972</td><td>7.0</td><td>SHAKTOOLIK AIRPORT, AK US</td><td>2018-01-08T01:00:00.000+0000</td><td>30</td><td>N</td><td>21</td><td>701</td><td>C</td><td>N</td><td>16093</td><td>null</td><td>-56</td><td>-72</td><td>10118</td><td>1</td><td>30.0</td><td>21.0</td><td>701.0</td><td>16093.0</td><td>-56.0</td><td>-72.0</td><td>10118.0</td></tr><tr><td>70388899999</td><td>2018-01-08T02:56:00.000+0000</td><td>64.3710833</td><td>-161.223972</td><td>7.0</td><td>SHAKTOOLIK AIRPORT, AK US</td><td>2018-01-08T02:00:00.000+0000</td><td>20</td><td>N</td><td>15</td><td>762</td><td>C</td><td>N</td><td>16093</td><td>null</td><td>-50</td><td>-72</td><td>10122</td><td>1</td><td>20.0</td><td>15.0</td><td>762.0</td><td>16093.0</td><td>-50.0</td><td>-72.0</td><td>10122.0</td></tr><tr><td>70388899999</td><td>2018-01-08T03:56:00.000+0000</td><td>64.3710833</td><td>-161.223972</td><td>7.0</td><td>SHAKTOOLIK AIRPORT, AK US</td><td>2018-01-08T03:00:00.000+0000</td><td>null</td><td>C</td><td>0</td><td>1036</td><td>9</td><td>N</td><td>16093</td><td>null</td><td>-61</td><td>-78</td><td>10126</td><td>0</td><td>96.0</td><td>0.0</td><td>1036.0</td><td>16093.0</td><td>-61.0</td><td>-78.0</td><td>10126.0</td></tr><tr><td>70388899999</td><td>2018-01-08T04:56:00.000+0000</td><td>64.3710833</td><td>-161.223972</td><td>7.0</td><td>SHAKTOOLIK AIRPORT, AK US</td><td>2018-01-08T04:00:00.000+0000</td><td>140</td ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Schema Checks

# %%
# Schema Checks | 

# flights.printSchema()
# stations.printSchema()
# weather.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- YEAR: integer (nullable = true)
# -- QUARTER: integer (nullable = true)
# -- MONTH: integer (nullable = true)
# -- DAY_OF_MONTH: integer (nullable = true)
# -- DAY_OF_WEEK: integer (nullable = true)
# -- FL_DATE: string (nullable = true)
# -- OP_UNIQUE_CARRIER: string (nullable = true)
# -- OP_CARRIER_AIRLINE_ID: integer (nullable = true)
# -- TAIL_NUM: string (nullable = true)
# -- OP_CARRIER_FL_NUM: integer (nullable = true)
# -- ORIGIN_AIRPORT_ID: integer (nullable = true)
# -- ORIGIN_AIRPORT_SEQ_ID: integer (nullable = true)
# -- ORIGIN: string (nullable = true)
# -- ORIGIN_CITY_NAME: string (nullable = true)
# -- ORIGIN_STATE_ABR: string (nullable = true)
# -- DEST_AIRPORT_ID: integer (nullable = true)
# -- DEST_AIRPORT_SEQ_ID: integer (nullable = true)
# -- DEST: string (nullable = true)
# -- DEST_CITY_NAME: string (nullable = true)
# -- DEST_STATE_ABR: string (nullable = true)
# -- CRS_DEP_TIME: integer (nullable = true)
# -- DEP_TIME: integer (nullable = true)
# -- DEP_DELAY: double (nullable = true)
# -- DEP_DELAY_NEW: double (nullable = true)
# -- DEP_DEL15: double (nullable = true)
# -- DEP_DELAY_GROUP: integer (nullable = true)
# -- DEP_TIME_BLK: string (nullable = true)
# -- TAXI_OUT: double (nullable = true)
# -- WHEELS_OFF: integer (nullable = true)
# -- WHEELS_ON: integer (nullable = true)
# -- TAXI_IN: double (nullable = true)
# -- CRS_ARR_TIME: integer (nullable = true)
# -- ARR_TIME: integer (nullable = true)
# -- ARR_DELAY: double (nullable = true)
# -- ARR_DELAY_NEW: double (nullable = true)
# -- ARR_DEL15: double (nullable = true)
# -- ARR_DELAY_GROUP: integer (nullable = true)
# -- ARR_TIME_BLK: string (nullable = true)
# -- CANCELLED: double (nullable = true)
# -- DIVERTED: double (nullable = true)
# -- CRS_ELAPSED_TIME: double (nullable = true)
# -- ACTUAL_ELAPSED_TIME: double (nullable = true)
# -- AIR_TIME: double (nullable = true)
# -- FLIGHTS: double (nullable = true)
# -- DISTANCE: double (nullable = true)
# -- DISTANCE_GROUP: integer (nullable = true)
# -- CARRIER_DELAY: double (nullable = true)
# -- WEATHER_DELAY: double (nullable = true)
# -- NAS_DELAY: double (nullable = true)
# -- SECURITY_DELAY: double (nullable = true)
# -- LATE_AIRCRAFT_DELAY: double (nullable = true)
# -- ID: string (nullable = true)
# -- IATA_ORIGIN: string (nullable = true)
# -- ICAO_ORIGIN: string (nullable = true)
# -- AIRPORT_LAT_ORIGIN: double (nullable = true)
# -- AIRPORT_LONG_ORIGIN: double (nullable = true)
# -- AIRPORT_TIMEZONE_ORIGIN: string (nullable = true)
# -- AIRPORT_UTC_OFFSET_ORIGIN: string (nullable = true)
# -- IATA_DEST: string (nullable = true)
# -- ICAO_DEST: string (nullable = true)
# -- AIRPORT_LAT_DEST: double (nullable = true)
# -- AIRPORT_LONG_DEST: double (nullable = true)
# -- AIRPORT_TIMEZONE_DEST: string (nullable = true)
# -- AIRPORT_UTC_OFFSET_DEST: string (nullable = true)
# -- CRS_DEP_TIME_UTC: timestamp (nullable = true)
# -- DEP_TIME_UTC: timestamp (nullable = true)
# -- ARR_TIME_UTC: timestamp (nullable = true)
# -- CRS_ARR_TIME_UTC: timestamp (nullable = true)
# -- CRS_DEP_TIME_UTC_HOUR: timestamp (nullable = true)
# -- CRS_ARR_TIME_UTC_HOUR: timestamp (nullable = true)
#
# root
# -- ICAO: string (nullable = true)
# -- WEATHER_STATION_ID: string (nullable = true)
#
# root
# -- YEAR: integer (nullable = true)
# -- QUARTER: integer (nullable = true)
# -- MONTH: integer (nullable = true)
# -- DAY_OF_MONTH: integer (nullable = true)
# -- DAY_OF_WEEK: integer (nullable = true)
# -- FL_DATE: string (nullable = true)
# -- OP_UNIQUE_CARRIER: string (nullable = true)
# -- OP_CARRIER_AIRLINE_ID: integer (nullable = true)
# -- TAIL_NUM: string (nullable = true)
# -- OP_CARRIER_FL_NUM: integer (nullable = true)
# -- ORIGIN_AIRPORT_ID: integer (nullable = true)
# -- ORIGIN_AIRPORT_SEQ_ID: integer (nullable = true)
# -- ORIGIN: string (nullable = true)
# -- ORIGIN_STATE_ABR: string (nullable = true)
# -- DEST_AIRPORT_ID: integer (nullable = true)
# -- DEST_AIRPORT_SEQ_ID: integer (nullable = true)
# -- DEST: string (nullable = true)
# -- DEST_STATE_ABR: string (nullable = true)
# -- CRS_DEP_TIME: integer (nullable = true)
# -- DEP_TIME: integer (nullable = true)
# -- DEP_DELAY: double (nullable = true)
# -- DEP_DELAY_NEW: double (nullable = true)
# -- DEP_DEL15: double (nullable = true)
# -- DEP_DELAY_GROUP: integer (nullable = true)
# -- DEP_TIME_BLK: string (nullable = true)
# -- TAXI_OUT: double (nullable = true)
# -- WHEELS_OFF: integer (nullable = true)
# -- WHEELS_ON: integer (nullable = true)
# -- TAXI_IN: double (nullable = true)
# -- CRS_ARR_TIME: integer (nullable = true)
# -- ARR_TIME: integer (nullable = true)
# -- ARR_DELAY: double (nullable = true)
# -- ARR_DELAY_NEW: double (nullable = true)
# -- ARR_DEL15: double (nullable = true)
# -- ARR_DELAY_GROUP: integer (nullable = true)
# -- ARR_TIME_BLK: string (nullable = true)
# -- CANCELLED: double (nullable = true)
# -- DIVERTED: double (nullable = true)
# -- CRS_ELAPSED_TIME: double (nullable = true)
# -- ACTUAL_ELAPSED_TIME: double (nullable = true)
# -- AIR_TIME: double (nullable = true)
# -- FLIGHTS: double (nullable = true)
# -- DISTANCE: double (nullable = true)
# -- DISTANCE_GROUP: integer (nullable = true)
# -- CARRIER_DELAY: double (nullable = true)
# -- WEATHER_DELAY: double (nullable = true)
# -- NAS_DELAY: double (nullable = true)
# -- SECURITY_DELAY: double (nullable = true)
# -- LATE_AIRCRAFT_DELAY: double (nullable = true)
# -- ID: string (nullable = true)
# -- IATA_ORIGIN: string (nullable = true)
# -- ICAO_ORIGIN: string (nullable = true)
# -- AIRPORT_LAT_ORIGIN: double (nullable = true)
# -- AIRPORT_LONG_ORIGIN: double (nullable = true)
# -- AIRPORT_TIMEZONE_ORIGIN: string (nullable = true)
# -- AIRPORT_UTC_OFFSET_ORIGIN: string (nullable = true)
# -- IATA_DEST: string (nullable = true)
# -- ICAO_DEST: string (nullable = true)
# -- AIRPORT_LAT_DEST: double (nullable = true)
# -- AIRPORT_LONG_DEST: double (nullable = true)
# -- AIRPORT_TIMEZONE_DEST: string (nullable = true)
# -- AIRPORT_UTC_OFFSET_DEST: string (nullable = true)
# -- CRS_DEP_TIME_UTC: timestamp (nullable = true)
# -- DEP_TIME_UTC: timestamp (nullable = true)
# -- ARR_TIME_UTC: timestamp (nullable = true)
# -- CRS_ARR_TIME_UTC: timestamp (nullable = true)
# -- CRS_DEP_TIME_UTC_HOUR: timestamp (nullable = true)
# -- CRS_ARR_TIME_UTC_HOUR: timestamp (nullable = true)
#
# </div>

# %%
# First, join flights to stations on ICAO - airport code which is a unique identifier we can use for both origin and destination
# In this join, we will be including:
#    - `WEATHER_STATION_ID`: the closest weather station which will then allow us to pull in weather at each airport

flights_w_stations = flights.join(stations, flights.ICAO_ORIGIN == stations.ICAO, 'left')\
                            .select(flights['*'], stations['WEATHER_STATION_ID'].alias('ORIGIN_WEATHER_STATION_ID'))\
                            .join(stations, flights.ICAO_DEST == stations.ICAO, 'left')\
                            .select(flights['*'], 'ORIGIN_WEATHER_STATION_ID', stations['WEATHER_STATION_ID'].alias('DEST_WEATHER_STATION_ID'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
origin_weather.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- ORIGIN_WEATHER_YEAR: integer (nullable = true)
# -- ORIGIN_WEATHER_QUARTER: integer (nullable = true)
# -- ORIGIN_WEATHER_MONTH: integer (nullable = true)
# -- ORIGIN_WEATHER_DAY_OF_MONTH: integer (nullable = true)
# -- ORIGIN_WEATHER_DAY_OF_WEEK: integer (nullable = true)
# -- ORIGIN_WEATHER_FL_DATE: string (nullable = true)
# -- ORIGIN_WEATHER_OP_UNIQUE_CARRIER: string (nullable = true)
# -- ORIGIN_WEATHER_OP_CARRIER_AIRLINE_ID: integer (nullable = true)
# -- ORIGIN_WEATHER_TAIL_NUM: string (nullable = true)
# -- ORIGIN_WEATHER_OP_CARRIER_FL_NUM: integer (nullable = true)
# -- ORIGIN_WEATHER_ORIGIN_AIRPORT_ID: integer (nullable = true)
# -- ORIGIN_WEATHER_ORIGIN_AIRPORT_SEQ_ID: integer (nullable = true)
# -- ORIGIN_WEATHER_ORIGIN: string (nullable = true)
# -- ORIGIN_WEATHER_ORIGIN_STATE_ABR: string (nullable = true)
# -- ORIGIN_WEATHER_DEST_AIRPORT_ID: integer (nullable = true)
# -- ORIGIN_WEATHER_DEST_AIRPORT_SEQ_ID: integer (nullable = true)
# -- ORIGIN_WEATHER_DEST: string (nullable = true)
# -- ORIGIN_WEATHER_DEST_STATE_ABR: string (nullable = true)
# -- ORIGIN_WEATHER_CRS_DEP_TIME: integer (nullable = true)
# -- ORIGIN_WEATHER_DEP_TIME: integer (nullable = true)
# -- ORIGIN_WEATHER_DEP_DELAY: double (nullable = true)
# -- ORIGIN_WEATHER_DEP_DELAY_NEW: double (nullable = true)
# -- ORIGIN_WEATHER_DEP_DEL15: double (nullable = true)
# -- ORIGIN_WEATHER_DEP_DELAY_GROUP: integer (nullable = true)
# -- ORIGIN_WEATHER_DEP_TIME_BLK: string (nullable = true)
# -- ORIGIN_WEATHER_TAXI_OUT: double (nullable = true)
# -- ORIGIN_WEATHER_WHEELS_OFF: integer (nullable = true)
# -- ORIGIN_WEATHER_WHEELS_ON: integer (nullable = true)
# -- ORIGIN_WEATHER_TAXI_IN: double (nullable = true)
# -- ORIGIN_WEATHER_CRS_ARR_TIME: integer (nullable = true)
# -- ORIGIN_WEATHER_ARR_TIME: integer (nullable = true)
# -- ORIGIN_WEATHER_ARR_DELAY: double (nullable = true)
# -- ORIGIN_WEATHER_ARR_DELAY_NEW: double (nullable = true)
# -- ORIGIN_WEATHER_ARR_DEL15: double (nullable = true)
# -- ORIGIN_WEATHER_ARR_DELAY_GROUP: integer (nullable = true)
# -- ORIGIN_WEATHER_ARR_TIME_BLK: string (nullable = true)
# -- ORIGIN_WEATHER_CANCELLED: double (nullable = true)
# -- ORIGIN_WEATHER_DIVERTED: double (nullable = true)
# -- ORIGIN_WEATHER_CRS_ELAPSED_TIME: double (nullable = true)
# -- ORIGIN_WEATHER_ACTUAL_ELAPSED_TIME: double (nullable = true)
# -- ORIGIN_WEATHER_AIR_TIME: double (nullable = true)
# -- ORIGIN_WEATHER_FLIGHTS: double (nullable = true)
# -- ORIGIN_WEATHER_DISTANCE: double (nullable = true)
# -- ORIGIN_WEATHER_DISTANCE_GROUP: integer (nullable = true)
# -- ORIGIN_WEATHER_CARRIER_DELAY: double (nullable = true)
# -- ORIGIN_WEATHER_WEATHER_DELAY: double (nullable = true)
# -- ORIGIN_WEATHER_NAS_DELAY: double (nullable = true)
# -- ORIGIN_WEATHER_SECURITY_DELAY: double (nullable = true)
# -- ORIGIN_WEATHER_LATE_AIRCRAFT_DELAY: double (nullable = true)
# -- ORIGIN_WEATHER_ID: string (nullable = true)
# -- ORIGIN_WEATHER_IATA_ORIGIN: string (nullable = true)
# -- ORIGIN_WEATHER_ICAO_ORIGIN: string (nullable = true)
# -- ORIGIN_WEATHER_AIRPORT_LAT_ORIGIN: double (nullable = true)
# -- ORIGIN_WEATHER_AIRPORT_LONG_ORIGIN: double (nullable = true)
# -- ORIGIN_WEATHER_AIRPORT_TIMEZONE_ORIGIN: string (nullable = true)
# -- ORIGIN_WEATHER_AIRPORT_UTC_OFFSET_ORIGIN: string (nullable = true)
# -- ORIGIN_WEATHER_IATA_DEST: string (nullable = true)
# -- ORIGIN_WEATHER_ICAO_DEST: string (nullable = true)
# -- ORIGIN_WEATHER_AIRPORT_LAT_DEST: double (nullable = true)
# -- ORIGIN_WEATHER_AIRPORT_LONG_DEST: double (nullable = true)
# -- ORIGIN_WEATHER_AIRPORT_TIMEZONE_DEST: string (nullable = true)
# -- ORIGIN_WEATHER_AIRPORT_UTC_OFFSET_DEST: string (nullable = true)
# -- ORIGIN_WEATHER_CRS_DEP_TIME_UTC: timestamp (nullable = true)
# -- ORIGIN_WEATHER_DEP_TIME_UTC: timestamp (nullable = true)
# -- ORIGIN_WEATHER_ARR_TIME_UTC: timestamp (nullable = true)
# -- ORIGIN_WEATHER_CRS_ARR_TIME_UTC: timestamp (nullable = true)
# -- ORIGIN_WEATHER_CRS_DEP_TIME_UTC_HOUR: timestamp (nullable = true)
# -- ORIGIN_WEATHER_CRS_ARR_TIME_UTC_HOUR: timestamp (nullable = true)
#
# </div>

# %%
# Second, we need to create a new timestamp to join weather on - which is lagged by 2 hours. 
# Due to the nature of our timestamps - we will actually have to subtract 3 hours to avoid leakage. 10800 is equivalent to 3 hours
flights_w_stations = flights_w_stations.withColumn('CRS_DEP_TIME_UTC_LAG', to_timestamp(f.col('CRS_DEP_TIME_UTC_HOUR').cast('long') - 10800))

# Next, prepend an origin or destination prefix to the weather columns, so when we join we know which weather set we're looking at
origin_weather = weather.select([f.col(weather_feat).alias('ORIGIN_WEATHER_'+weather_feat) for weather_feat in weather.columns])
dest_weather = weather.select([f.col(weather_feat).alias('DEST_WEATHER_'+weather_feat) for weather_feat in weather.columns])

# join flights to ORIGIN weather on station_id and our lagged ORIGIN time variable
flights_w_weather_temp = flights_w_stations.join(origin_weather, (flights_w_stations.ORIGIN_WEATHER_STATION_ID == origin_weather.ORIGIN_WEATHER_STATION) &\
                                                          (flights_w_stations.CRS_DEP_TIME_UTC_LAG == origin_weather.ORIGIN_WEATHER_HOUR), 
                                                          'left')

# Finally, join flights to DESTINATION weather on station_id and lagged ORIGIN time variable
flights_w_weather = flights_w_weather_temp.join(dest_weather, (flights_w_weather_temp.DEST_WEATHER_STATION_ID == dest_weather.DEST_WEATHER_STATION) &\
                                                          (flights_w_weather_temp.CRS_DEP_TIME_UTC_LAG == dest_weather.DEST_WEATHER_HOUR), 
                                                          'left')

# flights_w_weather_temp.count()
# flights_w_weather_temp.where(f.col('ID') == '2015-02-01N3MEAAORD730').display()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# display(flights_w_weather)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
JOINED_FULL_PROCESSED_PATH = blob_url + '/processed/joined_full_processed_df.parquet'

flights_w_weather.write.parquet(JOINED_FULL_PROCESSED_PATH)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
flights_in = spark.read.parquet(JOINED_FULL_PROCESSED_PATH).cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
flights_in.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: 30847753</div>

# %%
# flights_in.where(f.col('DEST_WEATHER_WND_SPEED_RATE-AVG').isNull()).groupBy(f.col('OP_UNIQUE_CARRIER')).count().display()
flights_in.where((f.col('ORIGIN_WEATHER_STATION').isNull()) | (f.col('DEST_WEATHER_STATION').isNull())).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: 72660</div>
